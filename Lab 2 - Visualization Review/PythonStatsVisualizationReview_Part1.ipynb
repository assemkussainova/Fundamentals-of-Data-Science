# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <font color="blue">Part 1</font>

# %% [markdown]
# ## Basic Statistics

# %%
# Store Iris dataset into the dataframe from the url source
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width', 'variety']
df_iris = pd.read_csv(url, names=names)

#print the first 10 elements of the dataframe
print(df_iris.head(10))
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# Compute the arithmetic mean of each feature in the dataset using the corresponding formula
mean = df_iris.iloc[:, :-1].sum()/len(df_iris)
print(mean)
# Out:
# sepal.length    5.843333
# sepal.width     3.054000
# petal.length    3.758667
# petal.width     1.198667
# dtype: float64

# %%
#  We can verify the previous answer by calling the built-in function
df_iris.mean()
# Out:
# sepal.length    5.843333
# sepal.width     3.054000
# petal.length    3.758667
# petal.width     1.198667
# dtype: float64

# %%
# We can also compute variance and std using the built-in functions
#print(df_iris.var())
print(df_iris.std())
# Out:
# sepal.length    0.828066
# sepal.width     0.433594
# petal.length    1.764420
# petal.width     0.763161
# dtype: float64

# %%
# Here we can compute 0.25th, 0.5th, 0.75th quantiles using build-in function
#print(df_iris.quantile(0.25))
#print(df_iris.quantile(0.5))
print(df_iris.quantile(0.75))
# also try print(df_iris.quantile([.25, .5, .75]))
# Out:
# sepal.length    6.4
# sepal.width     3.3
# petal.length    5.1
# petal.width     1.8
# Name: 0.75, dtype: float64

# %%
# We can get all of the metrics together 
df_iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### <font color="green">Your Turn: Iris</font>

# %%
# Compute variance of each feature in the dateset using the corresponding formula (see the slides for reference)
variance = ((df_iris.iloc[:, :-1] - mean) ** 2).sum()/(df_iris.shape[0]-1)
print(variance)
# Out:
# sepal.length    0.685694
# sepal.width     0.188004
# petal.length    3.113179
# petal.width     0.582414
# dtype: float64

# %%
# Compute standard deviation of each feature in the dateset using the corresponding formula (see the slides for reference)
standD = variance ** (1/2)
print(standD)
# Out:
# sepal.length    0.828066
# sepal.width     0.433594
# petal.length    1.764420
# petal.width     0.763161
# dtype: float64

# %%
# Compute 0.25th, 0.5th, 0.75th quantiles for 'sepal.length' using the corresponding formula (see the slides for reference)
q75, q50, q25 = np.percentile(df_iris["sepal.length"], [75, 50, 25])
print("0.75th quantile =", q75)
print("0.5th quantile =", q50)
print("0.25th quantile =", q25)
# Out:
# 0.75th quantile = 6.4
# 0.5th quantile = 5.8
# 0.25th quantile = 5.1

# %% [markdown]
# ## Visualization
# Matplotlib is a multiplatform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack. There are new packages available  that build on its powerful internals to drive Matplotlib via cleaner, more modern APIs. Pandas itself can be used as wrappers around Matplotlib’s API.

# %% [markdown]
# ### Line Plot
# You can find the documentation details here:
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
# Here is an example of line plots with Matplotlib
x = np.linspace(0, 10, 100)

# create a plot figure with fixed size
row_size = 5
column_size = 10
fig = plt.figure(figsize = (column_size,row_size))

# we can modify the style of the lines as follows
plt.plot(x, np.sin(x), linestyle = '--', label =  'f(x) = np.sin(x)')
plt.plot(x, np.cos(x), linestyle = ':', label = 'f(x) = np.cos(x)')
plt.plot(x, np.sin(x - 1), color='green', label = 'f(x) = np.sin(x - 1)')
plt.plot(x, np.cos(x - 1), color=[1.0,0.2,0.3], label = 'f(x) = np.cos(x - 1)')
plt.plot(x, x*0.1, '-.k', label = 'f(x) = x + 0.1')

# adding descriptions to the plot
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

plt.show()
# save in your local repository
fig.savefig('my_first_figure.png')

# %%
# You can get the list of supported output file formats
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# #### Note, this interface is stateful: it keeps track of the “current” figure and axes, which are where all plt commands are applied

# %%
row_size = 5
column_size = 10
# create a plot figure with fixed size
plt.figure(figsize = (column_size,row_size))
plt.suptitle('Only the second subplot axis are limited') 

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

#you can adjust the limits on both of the axis of a plot.
plt.xlim(2, 8)
plt.ylim(-.5, .5);
plt.show()

# %%
row_size = 5
column_size = 10
# Now we have access to each axis object
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(column_size,row_size))
fig.suptitle('Only the second subplot axis are limited') 
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
ax2.set(xlim=(2, 8), ylim=(-.5,.5))
ax1.set(xlim=(3, 8))

plt.show()

# %% [markdown]
# ### <font color="green">Your Turn: Arctic Data</font>

# %%
# Store the ArticData dataset in a dataframe
f = open('ArcticData.csv',newline='')
arctic_data = pd.read_csv(f)
arctic_data
# Out:
#      Month  Day  1980's Average  1990's Average  2000's Average      2002  \
# 0        1    1        13838002        13479932        12884425     -9999
# 1        1    2        13894654        13507159        12933153     -9999
# 2        1    3        13956651        13548447        12979517     -9999
# 3        1    4        14025305        13591262        13025972     -9999
# 4        1    5        14083638        13641693        13073337     -9999
# 5        1    6        14126244        13689257        13116894     -9999
# 6        1    7        14165180        13722489        13166041     -9999
# 7        1    8        14211925        13763992        13206788     -9999
# 8        1    9        14248750        13807015        13254035     -9999
# 9        1   10        14275316        13851768        13289116     -9999
# 10       1   11        14289704        13897130        13323718     -9999
# 11       1   12        14321332        13939465        13357576     -9999
# 12       1   13        14389859        13984146        13391870     -9999
# 13       1   14        14446923        14022152        13446337     -9999
# 14       1   15        14481697        14054389        13493118     -9999
# 15       1   16        14517793        14086178        13538353     -9999
# 16       1   17        14561142        14127684        13586512     -9999
# 17       1   18        14604837        14176870        13626683     -9999
# 18       1   19        14655020        14211380        13662810     -9999
# 19       1   20        14694661        14246930        13699875     -9999
# 20       1   21        14744586        14287687        13738144     -9999
# 21       1   22        14790602        14321095        13771697     -9999
# 22       1   23        14835232        14355513        13796679     -9999
# 23       1   24        14865088        14390678        13826934     -9999
# 24       1   25        14892317        14420009        13869499     -9999
# 25       1   26        14927068        14449206        13904422     -9999
# 26       1   27        14970633        14502222        13939440     -9999
# 27       1   28        15019479        14540199        13978476     -9999
# 28       1   29        15050695        14588000        14021279     -9999
# 29       1   30        15078152        14627246        14063086     -9999
# ..     ...  ...             ...             ...             ...       ...
# 336     12    2        12195666        11731207        11044904  11361354
# 337     12    3        12277514        11817983        11123727  11403556
# 338     12    4        12352890        11892871        11204147  11450376
# 339     12    5        12436576        11961229        11278309  11461042
# 340     12    6        12496564        12029964        11347817  11483087
# 341     12    7        12550502        12089458        11429231  11521713
# 342     12    8        12635829        12143225        11507702  11567943
# 343     12    9        12698048        12194959        11578062  11643067
# 25   13370205
# 26   13449609
# 27   13477989
# 28   13474856
# 29   13499512
# ..        ...
# 336     -9999
# 337     -9999
# 338     -9999
# 339     -9999
# 340     -9999
# 341     -9999
# 342     -9999
# 343     -9999
# 344     -9999
# 345     -9999
# 346     -9999
# 347     -9999
# 348     -9999
# 349     -9999
# 350     -9999
# 351     -9999
# 352     -9999
# 353     -9999
# 354     -9999
# 355     -9999
# 356     -9999
# 357     -9999
# 358     -9999
# 359     -9999
# 360     -9999
# 361     -9999
# 362     -9999
# 363     -9999
# 364     -9999
# 365     -9999
#
# [366 rows x 23 columns]

# %%
# Replace missing values (-9999) by NaN (np.nan)
# For the missing values propagate the previous values forward, along rows by specifying the axis
# Using Matplotlib, plot average monthly temparature for the years 2003 and 2018 in a single figure (hint: use groupby command)
# Show x-y labels and a legend
# Explore the documentation and change the ticks for the x axis such that each month is shown and change the labels to a corresponding description (i.e. 1 is January)
arctic_data = arctic_data.replace(to_replace = -9999, value = np.nan)
t = arctic_data.fillna(method = 'ffill', axis = 1)
t = t.groupby(['Month']).mean()

t.plot(y = ['2003', '2018'])
plt.xlabel('Month')
plt.ylabel('Average temperature')
plt.legend()

labels = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.xticks(np.arange(1, 13), labels, rotation='vertical')

plt.show()

# %% [markdown]
# ### Scatterplot
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
#
# The primary difference of plt.scatter from plt.plot is that it can be used to create
# scatter plots where the properties of each individual point (size, face color, edge color,
# etc.) can be individually controlled or mapped to data.
#
# __plt.scatter__ has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually. In __plt.plot__, on the other hand, the points are always essentially clones of each other, so the work of determining the appearance of the points is done only once for the entire set of data. For large datasets, the difference between these two can lead to vastly different performance, and for this reason, __plt.plot__ should be preferred over __plt.scatter__ for large datasets.
#
# (Adapted from https://jakevdp.github.io/PythonDataScienceHandbook/)

# %%
#Plot using matplotlib
plt.scatter(df_iris['sepal.length'],df_iris['sepal.width'],s=20,c='red')
plt.title('Scatter plot')
plt.xlabel('sepal.length')
plt.ylabel('sepal.width')
plt.show()

# %%
#Plot using pandas
ax = df_iris.plot.scatter('sepal.length','sepal.width',s=20,c='red', title='Scatter plot')

# %%
# We can also:
# modify the size of each marker based on one of the features 
# set the opacity level of color 
plt.scatter(df_iris['sepal.length'], df_iris['sepal.width'], alpha=0.2, s=100*df_iris['petal.length'], c = 'red')
plt.title('Scatter plot')
plt.xlabel(df_iris.columns[0])
plt.ylabel( df_iris.columns[1])
# Out:
# Text(0, 0.5, 'sepal.width')

# %%
# Here is the pandas variation (with different opacity and point sizes based on petal width)
ax = df_iris.plot.scatter(x=df_iris.columns[0], y=df_iris.columns[1], alpha = 0.5, s=100*df_iris.iloc[:,3], c='red', title='Scatter plot')

# %% [markdown]
# ### <font color="green">Your Turn: Cities</font>

# %%
# Store the cities dataset in a dataframe
f = open('Cities.csv',newline='')
cities = pd.read_csv(f)
cities
# Out:
#              city         country  latitude  longitude  temperature
# 0         Aalborg         Denmark     57.03       9.92         7.52
# 1        Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2          Abisko          Sweden     63.35      18.83         0.20
# 3           Adana          Turkey     36.99      35.32        18.67
# 4        Albacete           Spain     39.00      -1.87        12.62
# 5       Algeciras           Spain     36.13      -5.47        17.38
# 6          Amiens          France     49.90       2.30        10.17
# 7       Amsterdam     Netherlands     52.35       4.92         8.93
# 8          Ancona           Italy     43.60      13.50        13.52
# 9         Andorra         Andorra     42.50       1.52         9.60
# 10         Angers          France     47.48      -0.53        10.98
# 11         Ankara          Turkey     39.93      32.86         9.86
# 12        Antalya          Turkey     36.89      30.70        11.88
# 13           Arad         Romania     46.17      21.32         9.32
# 14         Athens          Greece     37.98      23.73        17.41
# 15       Augsburg         Germany     48.35      10.90         4.54
# 16          Bacau         Romania     46.58      26.92         7.51
# 17        Badajoz           Spain     38.88      -6.97        15.61
# 18      Baia Mare         Romania     47.66      23.58         8.87
# 19          Balti         Moldova     47.76      27.91         8.23
# 20      Barcelona           Spain     41.38       2.18        15.78
# 21           Bari           Italy     41.11      16.87        15.15
# 22          Basel     Switzerland     47.58       7.59         6.68
# 23         Batman          Turkey     37.89      41.14        14.16
# 24        Belfast  United Kingdom     54.60      -5.96         8.48
# 25       Belgrade          Serbia     44.82      20.47         9.85
# 26        Bergamo           Italy     45.70       9.67         9.12
# 27         Bergen          Norway     60.39       5.32         1.75
# 28         Berlin         Germany     52.52      13.40         8.72
# 29      Bialystok          Poland     53.15      23.17         6.07
# ..            ...             ...       ...        ...          ...
# 183         Split         Croatia     43.52      16.47        12.46
# 184  Stara Zagora        Bulgaria     42.42      25.62        10.90
# 185     Stavanger          Norway     58.97       5.68         5.53
# 186     Stockholm          Sweden     59.35      18.10         6.26
# 187          Sumy         Ukraine     50.92      34.78         6.28
# 188       Swansea  United Kingdom     51.63      -3.95         9.73
# 189        Szeged         Hungary     46.25      20.15        10.34
# 190       Tallinn         Estonia     59.43      24.73         4.82
# 191       Tampere         Finland     61.50      23.75         3.59
# 192        Tarsus          Turkey     36.92      34.88        11.21
# 193         Tartu         Estonia     58.38      26.71         4.36
# 194      Tekirdag          Turkey     40.99      27.51        13.02
# 195      Toulouse          France     43.62       1.45        10.25
# 196       Trabzon          Turkey     40.98      39.72        10.28
# 197       Trieste           Italy     45.65      13.80        11.21
# 198       Trikala          Greece     39.56      21.77        16.00
# 199     Trondheim          Norway     63.42      10.42         4.53
# 200         Turku         Finland     60.45      22.25         4.72
# 201       Uppsala          Sweden     59.86      17.64         4.17
# 202      Valencia           Spain     39.49      -0.40        16.02
# 203        Vienna         Austria     48.20      16.37         7.86
# 204          Vigo           Spain     42.22      -8.73        12.85
# 205       Vilnius       Lithuania     54.68      25.32         5.38
# 206        Warsaw          Poland     52.25      21.00         7.20
# 207       Wroclaw          Poland     51.11      17.03         7.17
# 208   Yevpatoriya         Ukraine     45.20      33.36        10.02
# 209      Zaragoza           Spain     41.65      -0.89        14.17
# 210      Zhytomyr         Ukraine     50.25      28.66         6.67
# 211     Zonguldak          Turkey     41.43      31.78        10.64
# 212        Zurich     Switzerland     47.38       8.56         6.68
#
# [213 rows x 5 columns]

# %%
# Using matplotlib, create a scatterplot of latitude (y) versus longitude (x) colored by temperature
# Provide labels for each axis and colormap
# Explore here the color maps, and use the most appropriate one
# https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html
plt.scatter(cities['longitude'], cities['latitude'], c = cities['temperature'], cmap = 'seismic')
plt.title('Scatter plot')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %%
# Using pandas plots, create as scatterplot of latitude (y) versus longitude (x) colored by temperature
# Again, use the appropriate color map
cities.plot.scatter(x = 'longitude', y = 'latitude', c = cities['temperature'], cmap = 'seismic')

# %% [markdown]
# ### Pie Chart
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.pie.html#pandas.Series.plot.pie

# %%
# Prepare the data
series_iris_grouped = df_iris.groupby('variety').size()
print(series_iris_grouped)
# Out:
# variety
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
series_iris_grouped.index
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='variety')

# %%
labels = series_iris_grouped.index
sizes = series_iris_grouped.values
explode = (0, 0.1, 0)  # only "explode" the 2nd slice 
plt.pie(sizes, labels=labels, shadow=True, startangle=90, autopct='%1.1f%%', explode=explode)
plt.title('The variety of Iris flowers')
plt.show()

# %%
ax = series_iris_grouped.plot(kind='pie', figsize=(4, 4), autopct='%1.1f%%', shadow=True, startangle=90, title='The variety of Iris flowers', explode = explode)
plt.ylabel('') # see why we need this line
plt.show()

# %% [markdown]
# ### <font color="green">Your Turn: Countries</font>

# %%
# Read the countries dataset into a dataframe
f = open('Countries.csv',newline='')
countries = pd.read_csv(f)
countries
# Out:
#                    country  population   EU coastline
# 0                  Albania        2.90   no       yes
# 1                  Andorra        0.07   no        no
# 2                  Austria        8.57  yes        no
# 3                  Belarus        9.48   no        no
# 4                  Belgium       11.37  yes       yes
# 5   Bosnia and Herzegovina        3.80   no       yes
# 6                 Bulgaria        7.10  yes       yes
# 7                  Croatia        4.23  yes       yes
# 8                   Cyprus        1.18  yes       yes
# 9           Czech Republic       10.55  yes        no
# 10                 Denmark        5.69  yes       yes
# 11                 Estonia        1.31  yes       yes
# 12                 Finland        5.52  yes       yes
# 13                  France       64.67  yes       yes
# 14                 Germany       80.68  yes       yes
# 15                  Greece       10.92  yes       yes
# 16                 Hungary        9.82  yes        no
# 17                 Iceland        0.33   no       yes
# 18                 Ireland        4.71  yes       yes
# 19                   Italy       59.80  yes       yes
# 20                  Kosovo        1.91   no        no
# 21                  Latvia        1.96  yes       yes
# 22           Liechtenstein        0.04   no        no
# 23               Lithuania        2.85  yes       yes
# 24              Luxembourg        0.58  yes        no
# 25               Macedonia        2.08   no        no
# 26                 Moldova        4.06   no        no
# 27              Montenegro        0.63   no       yes
# 28             Netherlands       16.98  yes       yes
# 29                  Norway        5.27   no       yes
# 30                  Poland       38.59  yes       yes
# 31                Portugal       10.30  yes       yes
# 32                 Romania       19.37  yes       yes
# 33                  Serbia        8.81   no        no
# 34                Slovakia        5.43  yes        no
# 35                Slovenia        2.07  yes       yes
# 36                   Spain       46.06  yes       yes
# 37                  Sweden        9.85  yes       yes
# 38             Switzerland        8.38   no        no
# 39                  Turkey       79.62   no       yes
# 40                 Ukraine       44.62   no       yes
# 41          United Kingdom       65.11  yes       yes

# %%
# Create pie chart using pandas showing the number counties with and without a coastline such that
# 1. the biggest portion is 'exploded' and red, while the other one is blue
# 2. set the font of the percetages to be white and bold
# Look at the provided documentation for hints
countries_grouped = countries.groupby('coastline').size()
explode = (0, 0.1)
plot = countries_grouped.plot.pie(autopct='%1.1f%%', textprops={'color':"w", 'weight':"bold"}, colors = ['blue', 'red'], explode = explode)
plt.title('Countries with and without a coastline')
plt.legend()
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Box Plot

# %% [markdown]
# Box Plot
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# Box Plot is the visual representation of the depicting groups of numerical data through their quartiles. Boxplot is also used for detect the outlier in data set. It captures the summary of the data efficiently with a simple box and whiskers and allows us to compare easily across groups. Boxplot summarizes a sample data using 25th, 50th and 75th percentiles. These percentiles are also known as the lower quartile, median and upper quartile.
#
# A box plot consist of 5 things.
# - Minimum
# - First Quartile or 25%
# - Median (Second Quartile) or 50%
# - Third Quartile or 75%
# - Maximum

# %%
# Plot boxplot using matplotlib
plt.figure(figsize = (5,5))
plt.boxplot(df_iris.iloc[:,:-1].values, notch=True, showfliers=True)
plt.show()

# %%
# Plot boxplot using pandas
ax= df_iris.boxplot()
plt.show()

# %%
# Plot boxplot of sepal lengths for different iris varieties
ax = df_iris.boxplot(by = 'variety', column='sepal.length', rot=30, fontsize=15, grid=False)
plt.ylabel('')
plt.xlabel('')
plt.title('')
plt.show()

# %% [markdown]
# ### <font color="green">Your Turn: Players and Countries</font>

# %%
# Using pandas, show the boxplots of the shots done by the players in different positions
f = open('Players.csv',newline='')
players = pd.read_csv(f)
ax = players.boxplot(by = 'position', column='shots', rot=30, fontsize=15, grid=False)
plt.ylabel('')
plt.xlabel('')
plt.title('')
plt.show()

# %%
# Using pandas, show the boxplots of populations of countries divided into two groups: in EU or not
ax = countries.boxplot(by = 'EU', column='population', fontsize=15, grid=False)
plt.ylabel('')
plt.xlabel('')
plt.title('')
plt.show()

# %% [markdown]
# ### Histogram Plot
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
#
# Histograms are a type of bar plot for numeric data that group the data into bins.

# %%
# Plot histogram of sepal length using matplotlib
plt.figure(figsize = (5,5))
plt.hist(df_iris['sepal.length'], bins = 40, alpha=0.5)
plt.title('The variety of Iris flowers')
plt.xlabel('sepal length')
plt.ylabel('frequency')
plt.show()

# %%
# Plot histogram of sepal length using pandas
df_iris[['sepal.length']].plot.hist(bins = 40, alpha = 0.5, figsize = (5,5))
plt.show()

# %%
# Plot histogram of all features of iris
df_iris.plot.hist(bins = 80, alpha = 0.5, figsize = (10,10))
plt.show()

# %%
# Note that in pandas you can also drop the 'plot' and directly call the 'hist' function which returns a list of axes corresponding to each feature.
df_iris.hist(bins = 40, alpha = 0.5, figsize = (10,10))
plt.show()

# %% [markdown]
# ### <font color="green">Your Turn: Players</font>

# %%
#Using pandas, plot histograms with 20 bins of the numerical features in the dataset such that:
#1. A figure with multiple subplots where each feature has its own histogram
players.hist(bins = 20, alpha = 0.5, figsize = (15,15))
plt.show()

# %%
#2. A figure with mulitple subplots where histograms of the features with similar scale are combined together into one
players[["minutes", "passes"]].plot.hist(bins = 20, alpha = 0.4)
players[["shots", "tackles"]].plot.hist(bins = 20, alpha = 0.4)
players[["saves"]].plot.hist(bins = 20, alpha = 0.4)
